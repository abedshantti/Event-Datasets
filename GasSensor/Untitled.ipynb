# %%
import pandas as pd

# %%
read_df = pd.read_csv('HT_Sensor_metadata.dat', sep='\t',header = 0)

# %%
read_df.head()
# Out:
#    id      date Unnamed: 2  class    t0  dt
# 0   0  07-04-15     banana  13.49  1.64 NaN
# 1   1  07-05-15       wine  19.61  0.54 NaN
# 2   2  07-06-15       wine  19.99  0.66 NaN
# 3   3  07-09-15     banana   6.49  0.72 NaN
# 4   4  07-09-15       wine  20.07  0.53 NaN

# %%
read_df  = read_df.drop("dt", axis = 1)
read_df.columns = ["id", "date", "class", "t0", "dt"]
read_df.to_csv("sensor_metadata.csv", index = False)

# %%
labels_df = pd.read_csv("sensor_metadata.csv")
labels_df = labels_df.drop(["date", "t0", "dt"], axis = 1)
labels_df.to_csv("targets.csv", index = False)

# %%
labels_df.head()
# Out:
#    id   class
# 0   0  banana
# 1   1    wine
# 2   2    wine
# 3   3  banana
# 4   4    wine

# %%
labels_df["class"].value_counts()
# Out:
# wine          36
# banana        33
# background    31
# Name: class, dtype: int64

# %%
df = pd.read_csv("HTsensor.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  id      time       R1       R2       R3       R4       R5  \
# 0           1   0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931
# 1           2   0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927
# 2           3   0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924
# 3           4   0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921
# 4           5   0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919
#
#         R6       R7       R8    Temp.  Humidity  0
# 0  13.3423  8.04169  8.73901  26.2257   59.0528  1
# 1  13.3412  8.04133  8.73908  26.2308   59.0299  1
# 2  13.3405  8.04101  8.73915  26.2365   59.0093  1
# 3  13.3398  8.04086  8.73936  26.2416   58.9905  1
# 4  13.3390  8.04087  8.73986  26.2462   58.9736  1

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df.head()
# Out:
#    id      time       R1       R2       R3       R4       R5       R6  \
# 0   0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1   0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2   0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3   0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4   0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
#
#         R7       R8    Temp.  Humidity  0
# 0  8.04169  8.73901  26.2257   59.0528  1
# 1  8.04133  8.73908  26.2308   59.0299  1
# 2  8.04101  8.73915  26.2365   59.0093  1
# 3  8.04086  8.73936  26.2416   58.9905  1
# 4  8.04087  8.73986  26.2462   58.9736  1

# %%
data_df = pd.read_csv("HT_Sensor_dataset.dat",sep = '  ',header = 0,engine='python')
#dataset.columns = ['id','time','R1','R2','R3','R4','R5','R6','R7','R8','Temp.','Humidity']
#dataset.set_index('id',inplace = True)
#dataset.head()

# %%
data_df.head()
# Out:
#    id time\t  Unnamed: 1  Unnamed: 2       R1  Unnamed: 4  Unnamed: 5  \
# 0          0   -0.999750     12.8621  10.3683     10.4383     11.6699
# 1          0   -0.999472     12.8617  10.3682     10.4375     11.6697
# 2          0   -0.999194     12.8607  10.3686     10.4370     11.6696
# 3          0   -0.998916     12.8602  10.3686     10.4370     11.6697
# 4          0   -0.998627     12.8595  10.3688     10.4374     11.6699
#
#    Unnamed: 6       R2  Unnamed: 8  Unnamed: 9  ...  Unnamed: 29  Unnamed: 30  \
# 0     13.4931  13.3423     8.04169     8.73901  ...          NaN          NaN
# 1     13.4927  13.3412     8.04133     8.73908  ...          NaN          NaN
# 2     13.4924  13.3405     8.04101     8.73915  ...          NaN          NaN
# 3     13.4921  13.3398     8.04086     8.73936  ...          NaN          NaN
# 4     13.4919  13.3390     8.04087     8.73986  ...          NaN          NaN
#
# ...

# %%
data_df.columns
# Out:
# Index(['id time\t', 'Unnamed: 1', 'Unnamed: 2', 'R1', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', ' R2', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', ' R3', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        ' R4', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', ' R5',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', ' R6', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', ' R7', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'R8', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Temp.', 'Unnamed: 36', 'Unnamed: 37', 'Humidity'],
#       dtype='object')

# %%
data_df['id time\t'].value_counts()
# Out:
# 38    15393
# 32    14148
# 25    13441
# 39    13174
# 57    13140
#       ...
# 11     6526
# 20     6174
# 4      5396
# 14     4922
# 76     3825
# Name: id time\t, Length: 99, dtype: int64

# %%
cols_del = ['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
       ' R4', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', ' R5',
       'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', ' R6', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', ' R7', 'Unnamed: 28', 'Unnamed: 29',
       'Unnamed: 30', 'R8', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
       'Temp.', 'Unnamed: 36', 'Unnamed: 37', 'Humidity']

data_df = data_df.drop(cols_del, axis = 1)

# %%
data_df.columns = ['id','time','R1','R2','R3','R4','R5','R6','R7','R8','Temp.','Humidity']

# %%
data_df.head()
# Out:
#    id      time       R1       R2       R3       R4       R5       R6  \
# 0   0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1   0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2   0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3   0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4   0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
#
#         R7       R8    Temp.  Humidity
# 0  8.04169  8.73901  26.2257   59.0528
# 1  8.04133  8.73908  26.2308   59.0299
# 2  8.04101  8.73915  26.2365   59.0093
# 3  8.04086  8.73936  26.2416   58.9905
# 4  8.04087  8.73986  26.2462   58.9736

# %%
data_df["time_diff"] = data_df.groupby("id")["time"].diff()

# %%
data_df.head()
# Out:
#    id      time       R1       R2       R3       R4       R5       R6  \
# 0   0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1   0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2   0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3   0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4   0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
#
#         R7       R8    Temp.  Humidity  time_diff
# 0  8.04169  8.73901  26.2257   59.0528        NaN
# 1  8.04133  8.73908  26.2308   59.0299   0.000278
# 2  8.04101  8.73915  26.2365   59.0093   0.000278
# 3  8.04086  8.73936  26.2416   58.9905   0.000278
# 4  8.04087  8.73986  26.2462   58.9736   0.000289

# %%
data_df = data_df.drop("time", axis = 1)
data_df.to_csv("data.csv", index = False)
