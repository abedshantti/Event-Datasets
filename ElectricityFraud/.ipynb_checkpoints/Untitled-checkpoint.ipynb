# %%
import pandas as pd
import numpy as np

# %%
label_df = pd.read_csv("client_train.csv")

# %%
target_good = 4
num_bad_candidates = label_df["target"].value_counts()[1.0]
num_good_candidates = target_good * num_bad_candidates

# %%
bad_clients = label_df[label_df["target"]==1.0]["client_id"].tolist()
good_clients = label_df[label_df["target"]==0.0]["client_id"].tolist()

# %%
import random
rnd_seed = 35
random.Random(rnd_seed).shuffle(good_clients)

# %%
short_good_clients = good_clients[:num_good_candidates]

# %%
clients = short_good_clients + bad_clients
targets = [0]*num_good_candidates + [1]*num_bad_candidates

# %%
clients_df = pd.DataFrame({"client": clients, "target": targets})
clients_df = clients_df.sort_values("client")
clients_df.to_csv("targets.csv", index = False)

# %%
# df_1 = pd.read_csv("invoice_train.csv", nrows = chunk_size)
# df_2 = pd.read_csv("invoice_train.csv", nrows = chunk_size, skip_rows = chunk_size)
# df_3 = pd.read_csv("invoice_train.csv", nrows = chunk_size, skip_rows = chunk_size*2)
# df_4 = pd.read_csv("invoice_train.csv", nrows = chunk_size, skip_rows = chunk_size*3)
# df_5 = pd.read_csv("invoice_train.csv", nrows = chunk_size, skip_rows = chunk_size*4)

# %%
chunk_size = 1000000
reading_iters = 5
data_df = pd.DataFrame()
for i in range(0, reading_iters):
    if i == 0:
        read_df = pd.read_csv("invoice_train.csv", header = 0, nrows = chunk_size )
    else:
        read_df = pd.read_csv("invoice_train.csv", header = 0, nrows = chunk_size, skiprows = range(1, chunk_size * i) )
    filter_df = read_df[read_df["client_id"].isin(clients)]
    data_df = pd.concat([data_df, filter_df])
# Out:
# C:\Users\aaalshan\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_df.head()
# Out:
#           client_id invoice_date  tarif_type  counter_number counter_statue  \
# 72  train_Client_10   2010-02-15          11          572765              0
# 73  train_Client_10   2015-03-06          11          572765              0
# 74  train_Client_10   2009-02-13          11          572765              0
# 75  train_Client_10   2019-05-02          11          572765              0
# 76  train_Client_10   2017-05-30          11          572765              0
#
#     counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 72           203                 8                    1                   407
# 73           203                 8                    1                   815
# 74           203                 6                    1                   569
# 75           207                 9                    1                  2400
# 76           203                 8                    1                   188
#
#     consommation_level_2  consommation_level_3  consommation_level_4  \
# 72                     0                     0                     0
# 73                     0                     0                     0
# 74                     0                     0                     0
# 75                   682                     0                     0
# 76                     0                     0                     0
#
#     old_index  new_index  months_number counter_type
# 72      31955      32362              4         ELEC
# 73      37913      38728              8         ELEC
# 74      30414      30983              4         ELEC
# 75      41532      44614             12         ELEC
# 76      40634      40822              4         ELEC

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1324208 entries, 72 to 476749
# Data columns (total 16 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   client_id             1324208 non-null  object
#  1   invoice_date          1324208 non-null  object
#  2   tarif_type            1324208 non-null  int64
#  3   counter_number        1324208 non-null  int64
#  4   counter_statue        1324208 non-null  object
#  5   counter_code          1324208 non-null  int64
#  6   reading_remarque      1324208 non-null  int64
#  7   counter_coefficient   1324208 non-null  int64
#  8   consommation_level_1  1324208 non-null  int64
#  9   consommation_level_2  1324208 non-null  int64
#  10  consommation_level_3  1324208 non-null  int64
#  11  consommation_level_4  1324208 non-null  int64
#  12  old_index             1324208 non-null  int64
#  13  new_index             1324208 non-null  int64
#  14  months_number         1324208 non-null  int64
#  15  counter_type          1324208 non-null  object
# dtypes: int64(12), object(4)
# memory usage: 171.7+ MB

# %%
data_df["months_number"].value_counts()
# Out:
# 4         1077855
# 8           82116
# 2           81360
# 1           43747
# 12          15736
#            ...
# 239116          1
# 229890          1
# 57964           1
# 81480           1
# 363697          1
# Name: months_number, Length: 608, dtype: int64

# %%
#data_df["consumption"] = data_df["consommation_level_1"] + data_df["consommation_level_2"] + data_df["consommation_level_3"] + data_df["consommation_level_4"]
data_df["invoice_date"] = pd.to_datetime(data_df["invoice_date"], format="%Y-%m-%d")
data_df = data_df.sort_values(["client_id", "invoice_date"])
data_df = data_df.drop(["new_index", "counter_number", "months_number"], axis=1)

# %%
data_df.head()
# Out:
#           client_id invoice_date  tarif_type counter_statue  counter_code  \
# 89  train_Client_10   2005-11-10          11              0           203
# 88  train_Client_10   2006-06-19          11              0           203
# 86  train_Client_10   2007-06-18          11              0           203
# 85  train_Client_10   2007-10-16          11              0           203
# 84  train_Client_10   2008-02-15          11              0           203
#
#     reading_remarque  counter_coefficient  consommation_level_1  \
# 89                 6                    1                   459
# 88                 6                    1                   931
# 86                 6                    1                  1355
# 85                 6                    1                   476
# 84                 6                    1                   761
#
#     consommation_level_2  consommation_level_3  consommation_level_4  \
# 89                     0                     0                     0
# 88                     0                     0                     0
# 86                     0                     0                     0
# 85                     0                     0                     0
# 84                     0                     0                     0
#
#     old_index counter_type
# 89      25515         ELEC
# 88      25974         ELEC
# 86      26905         ELEC
# 85      28260         ELEC
# 84      28736         ELEC

# %%
data_df["counter_statue"].value_counts()
# Out:
# 0    1284422
# 1      21430
# 0      10704
# 5       6483
# 4        876
# 1        154
# 3         51
# 5         49
# 4         32
# 2          7
# Name: counter_statue, dtype: int64

# %%
data_df["counter_coefficient"].value_counts()
# Out:
# 1     1323982
# 30        137
# 3          56
# 2          19
# 4           5
# 20          3
# 0           3
# 33          1
# 10          1
# 5           1
# Name: counter_coefficient, dtype: int64

# %%
label_df.head()
# Out:
#    disrict          client_id  client_catg  region creation_date  target
# 0       60     train_Client_0           11     101    31/12/1994     0.0
# 1       69     train_Client_1           11     107    29/05/2002     0.0
# 2       62    train_Client_10           11     301    13/03/1986     0.0
# 3       69   train_Client_100           11     105    11/07/1996     0.0
# 4       62  train_Client_1000           11     303    14/10/2014     0.0

# %%
data_df = data_df.merge(label_df, how="left", on="client_id")

# %%
data_df.head()
# Out:
#          client_id invoice_date  tarif_type counter_statue  counter_code  \
# 0  train_Client_10   2005-11-10          11              0           203
# 1  train_Client_10   2006-06-19          11              0           203
# 2  train_Client_10   2007-06-18          11              0           203
# 3  train_Client_10   2007-10-16          11              0           203
# 4  train_Client_10   2008-02-15          11              0           203
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0                 6                    1                   459
# 1                 6                    1                   931
# 2                 6                    1                  1355
# 3                 6                    1                   476
# 4                 6                    1                   761
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index counter_type  disrict  client_catg  region creation_date  target
# 0      25515         ELEC       62           11     301    13/03/1986     0.0
# 1      25974         ELEC       62           11     301    13/03/1986     0.0
# 2      26905         ELEC       62           11     301    13/03/1986     0.0
# 3      28260         ELEC       62           11     301    13/03/1986     0.0
# 4      28736         ELEC       62           11     301    13/03/1986     0.0

# %%
data_df.head()
# Out:
#          client_id invoice_date  tarif_type counter_statue  counter_code  \
# 0  train_Client_10   2005-11-10          11              0           203
# 1  train_Client_10   2006-06-19          11              0           203
# 2  train_Client_10   2007-06-18          11              0           203
# 3  train_Client_10   2007-10-16          11              0           203
# 4  train_Client_10   2008-02-15          11              0           203
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0                 6                    1                   459
# 1                 6                    1                   931
# 2                 6                    1                  1355
# 3                 6                    1                   476
# 4                 6                    1                   761
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index counter_type  disrict  client_catg  region creation_date  target
# 0      25515         ELEC       62           11     301    13/03/1986     0.0
# 1      25974         ELEC       62           11     301    13/03/1986     0.0
# 2      26905         ELEC       62           11     301    13/03/1986     0.0
# 3      28260         ELEC       62           11     301    13/03/1986     0.0
# 4      28736         ELEC       62           11     301    13/03/1986     0.0

# %%
data_df["creation_date"] = pd.to_datetime(data_df["creation_date"], format="%d/%m/%Y")
data_df["days_since_previous_invoice"] = data_df.groupby("client_id")["invoice_date"].diff().dt.days

# %%
data_df.tail()
# Out:
#                   client_id invoice_date  tarif_type counter_statue  \
# 1324203  train_Client_99996   2019-06-18          40              0
# 1324204  train_Client_99996   2019-06-18          11              0
# 1324205  train_Client_99999   1996-01-25          11              0
# 1324206  train_Client_99999   1996-05-28          11              0
# 1324207  train_Client_99999   1996-09-25          11              0
#
#          counter_code  reading_remarque  counter_coefficient  \
# 1324203             5                 9                    1
# 1324204           207                 9                    1
# 1324205           203                 6                    1
# 1324206           203                 6                    1
# 1324207           203                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 1324203                   137                     0                     0
# 1324204                   365                     0                     0
# 1324205                   516                     0                     0
# 1324206                   603                     0                     0
# 1324207                   259                     0                     0
#
#          consommation_level_4  old_index counter_type  disrict  client_catg  \
# 1324203                     0       1289          GAZ       63           11
# 1324204                     0       5860         ELEC       63           11
# 1324205                     0      12765         ELEC       60           11
# 1324206                     0      13281         ELEC       60           11
# 1324207                     0      13884         ELEC       60           11
#
#          region creation_date  target  days_since_previous_invoice
# 1324203     311    2012-10-25     0.0                        124.0
# 1324204     311    2012-10-25     0.0                          0.0
# 1324205     101    1986-02-18     0.0                          NaN
# 1324206     101    1986-02-18     0.0                        124.0
# 1324207     101    1986-02-18     0.0                        120.0

# %%
(data_df.loc[1324207, "invoice_date"].year - data_df.loc[1324207, "creation_date"].year) * 12 + (data_df.loc[1324207, "invoice_date"].month - data_df.loc[1324207, "creation_date"].month)
# Out:
# 127

# %%
grp_acc_crt = data_df.groupby("client_id").apply(lambda x: (x["invoice_date"].dt.year - x["creation_date"].dt.year)*12 + (x["invoice_date"].dt.month - x["creation_date"].dt.month)).reset_index()

# %%
grp_acc_crt
# Out:
#                   client_id  level_1    0
# 0           train_Client_10        0  236
# 1           train_Client_10        1  243
# 2           train_Client_10        2  255
# 3           train_Client_10        3  259
# 4           train_Client_10        4  263
# ...                     ...      ...  ...
# 1324203  train_Client_99996  1324203   80
# 1324204  train_Client_99996  1324204   80
# 1324205  train_Client_99999  1324205  119
# 1324206  train_Client_99999  1324206  123
# 1324207  train_Client_99999  1324207  127
#
# [1324208 rows x 3 columns]

# %%
grp_acc_crt = grp_acc_crt.set_index("level_1")
grp_acc_crt = grp_acc_crt.drop("client_id", axis = 1)
grp_acc_crt.index.name = None
grp_acc_crt.columns = ["months_since_acc_creation"]

# %%
data_df = data_df.join(grp_acc_crt, how="left")

# %%
data_df.head()
# Out:
#          client_id invoice_date  tarif_type counter_statue  counter_code  \
# 0  train_Client_10   2005-11-10          11              0           203
# 1  train_Client_10   2006-06-19          11              0           203
# 2  train_Client_10   2007-06-18          11              0           203
# 3  train_Client_10   2007-10-16          11              0           203
# 4  train_Client_10   2008-02-15          11              0           203
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0                 6                    1                   459
# 1                 6                    1                   931
# 2                 6                    1                  1355
# 3                 6                    1                   476
# 4                 6                    1                   761
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index counter_type  disrict  client_catg  region creation_date  target  \
# 0      25515         ELEC       62           11     301    1986-03-13     0.0
# 1      25974         ELEC       62           11     301    1986-03-13     0.0
# 2      26905         ELEC       62           11     301    1986-03-13     0.0
# 3      28260         ELEC       62           11     301    1986-03-13     0.0
# 4      28736         ELEC       62           11     301    1986-03-13     0.0
#
#    days_since_previous_invoice  months_since_acc_creation
# 0                          NaN                        236
# 1                        221.0                        243
# 2                        364.0                        255
# 3                        120.0                        259
# 4                        122.0                        263

# %%
#data_df = data_df.drop(["invoice_date", "creation_date", "target"], axis = 1)

# %%
data_df.describe()
# Out:
#          tarif_type  counter_code  reading_remarque  counter_coefficient  \
# count  1.324208e+06  1.324208e+06      1.324208e+06         1.324208e+06
# mean   2.025715e+01  1.725996e+02      7.321801e+00         1.003185e+00
# std    1.352044e+01  1.351177e+02      1.358412e+00         2.981313e-01
# min    8.000000e+00  5.000000e+00      6.000000e+00         0.000000e+00
# 25%    1.100000e+01  5.000000e+00      6.000000e+00         1.000000e+00
# 50%    1.100000e+01  2.030000e+02      8.000000e+00         1.000000e+00
# 75%    4.000000e+01  2.070000e+02      9.000000e+00         1.000000e+00
# max    4.500000e+01  6.000000e+02      9.000000e+00         3.300000e+01
#
#        consommation_level_1  consommation_level_2  consommation_level_3  \
# count          1.324208e+06          1.324208e+06          1.324208e+06
# mean           4.152688e+02          1.150730e+02          2.311134e+01
# std            6.221932e+02          1.195045e+03          1.847334e+02
# min            0.000000e+00          0.000000e+00          0.000000e+00
# 25%            8.100000e+01          0.000000e+00          0.000000e+00
# 50%            2.700000e+02          0.000000e+00          0.000000e+00
# 75%            6.010000e+02          0.000000e+00          0.000000e+00
# max            1.261180e+05          9.990730e+05          6.449200e+04
#
#        consommation_level_4     old_index       disrict   client_catg  \
# count          1.324208e+06  1.324208e+06  1.324208e+06  1.324208e+06
# mean           6.049170e+01  1.877862e+04  6.362777e+01  1.230907e+01
# std            8.989202e+02  4.284750e+04  3.307692e+00  7.076982e+00
# min            0.000000e+00  0.000000e+00  6.000000e+01  1.100000e+01
# 25%            0.000000e+00  1.884000e+03  6.200000e+01  1.100000e+01
# 50%            0.000000e+00  7.931000e+03  6.300000e+01  1.100000e+01
# 75%            0.000000e+00  2.229000e+04  6.900000e+01  1.100000e+01
# max            5.479460e+05  1.476203e+06  6.900000e+01  5.100000e+01
#
#              region        target  days_since_previous_invoice  \
# count  1.324208e+06  1.324208e+06                 1.286378e+06
# mean   2.113651e+02  2.666590e-01                 9.308717e+01
# std    1.036136e+02  4.422128e-01                 1.135928e+02
# min    1.010000e+02  0.000000e+00                 0.000000e+00
# 25%    1.030000e+02  0.000000e+00                 0.000000e+00
# 50%    3.010000e+02  0.000000e+00                 8.500000e+01
# 75%    3.090000e+02  1.000000e+00                 1.260000e+02
# max    3.990000e+02  1.000000e+00                 3.740000e+03
#
#        months_since_acc_creation
# count               1.324208e+06
# mean                1.669032e+02
# std                 1.222185e+02
# min                -1.000000e+01
# 25%                 6.300000e+01
# 50%                 1.400000e+02
# 75%                 2.590000e+02
# max                 5.140000e+02

# %%
sanity_df = data_df[data_df["months_since_acc_creation"] < 0]

# %%
sanity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3303 entries, 496 to 1323451
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   client_id                    3303 non-null   object
#  1   invoice_date                 3303 non-null   datetime64[ns]
#  2   tarif_type                   3303 non-null   int64
#  3   counter_statue               3303 non-null   object
#  4   counter_code                 3303 non-null   int64
#  5   reading_remarque             3303 non-null   int64
#  6   counter_coefficient          3303 non-null   int64
#  7   consommation_level_1         3303 non-null   int64
#  8   consommation_level_2         3303 non-null   int64
#  9   consommation_level_3         3303 non-null   int64
#  10  consommation_level_4         3303 non-null   int64
#  11  old_index                    3303 non-null   int64
#  12  counter_type                 3303 non-null   object
#  13  disrict                      3303 non-null   int64
#  14  client_catg                  3303 non-null   int64
#  15  region                       3303 non-null   int64
#  16  creation_date                3303 non-null   datetime64[ns]
#  17  target                       3303 non-null   float64
#  18  days_since_previous_invoice  1286 non-null   float64
#  19  months_since_acc_creation    3303 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(13), object(3)
# memory usage: 541.9+ KB

# %%
sanity_df.head(10)
# Out:
#                 client_id invoice_date  tarif_type counter_statue  \
# 496   train_Client_100074   2014-01-12          11              0
# 497   train_Client_100074   2014-01-12          40              0
# 2116  train_Client_100235   2011-02-11          11              0
# 3355  train_Client_100344   2016-01-12          11              0
# 3364  train_Client_100347   2009-05-10          40              0
# 3365  train_Client_100347   2009-05-10          11              0
# 3559  train_Client_100358   2010-06-10          11              1
# 4026  train_Client_100403   2007-05-12          11              1
# 4518  train_Client_100439   2008-01-09          40              0
# 4519  train_Client_100439   2008-01-09          11              0
#
#       counter_code  reading_remarque  counter_coefficient  \
# 496            207                 9                    1
# 497              5                 9                    1
# 2116           203                 6                    1
# 3355           207                 6                    1
# 3364             5                 6                    1
# 3365           207                 6                    1
# 3559           203                 6                    1
# 4026           203                 6                    1
# 4518             5                 6                    1
# 4519           207                 9                    1
#
#       consommation_level_1  consommation_level_2  consommation_level_3  \
# 496                     41                     0                     0
# 497                     60                     0                     0
# 2116                    36                     0                     0
# 3355                    70                     0                     0
# 3364                    14                     0                     0
# 3365                     0                     0                     0
# 3559                   405                     0                     0
# 4026                   378                     0                     0
# 4518                     0                     0                     0
# 4519                   936                     0                     0
#
#       consommation_level_4  old_index counter_type  disrict  client_catg  \
# 496                      0         36         ELEC       63           11
# 497                      0          8          GAZ       63           11
# 2116                     0          6         ELEC       62           11
# 3355                     0          0         ELEC       62           11
# 3364                     0          0          GAZ       62           11
# 3365                     0          0         ELEC       62           11
# 3559                     0          0         ELEC       60           11
# 4026                     0      19742         ELEC       63           11
# 4518                     0         16          GAZ       69           11
# 4519                     0         32         ELEC       69           11
#
#       region creation_date  target  days_since_previous_invoice  \
# 496      312    2014-04-07     0.0                          NaN
# 497      312    2014-04-07     0.0                          0.0
# 2116     302    2011-05-17     1.0                          NaN
# 3355     302    2016-08-04     0.0                          NaN
# 3364     301    2009-06-23     0.0                          NaN
# 3365     301    2009-06-23     0.0                          0.0
# 3559     101    2010-08-14     0.0                          NaN
# 4026     312    2007-10-26     0.0                          NaN
# 4518     103    2008-02-15     1.0                          NaN
# 4519     103    2008-02-15     1.0                          0.0
#
#       months_since_acc_creation
# 496                          -3
# 497                          -3
# 2116                         -3
# 3355                         -7
# 3364                         -1
# 3365                         -1
# 3559                         -2
# 4026                         -5
# 4518                         -1
# 4519                         -1

# %%
one_acc_df = data_df[data_df["client_id"] == "train_Client_100074"]

# %%
one_acc_df.head(40)
# Out:
#                client_id invoice_date  tarif_type counter_statue  \
# 496  train_Client_100074   2014-01-12          11              0
# 497  train_Client_100074   2014-01-12          40              0
# 498  train_Client_100074   2014-07-24          11              0
# 499  train_Client_100074   2014-07-24          40              0
# 500  train_Client_100074   2015-03-30          40              0
# 501  train_Client_100074   2015-03-30          11              0
# 502  train_Client_100074   2015-07-23          40              0
# 503  train_Client_100074   2015-07-23          11              0
# 504  train_Client_100074   2015-11-25          40              0
# 505  train_Client_100074   2015-11-25          11              0
# 506  train_Client_100074   2016-03-24          40              0
# 507  train_Client_100074   2016-03-24          11              0
# 508  train_Client_100074   2016-07-26          40              0
# 509  train_Client_100074   2016-07-26          11              0
# 510  train_Client_100074   2016-11-23          11              0
# 511  train_Client_100074   2016-11-23          40              0
# 512  train_Client_100074   2017-03-23          40              0
# 513  train_Client_100074   2017-03-23          11              0
# 514  train_Client_100074   2017-07-21          40              0
# 515  train_Client_100074   2017-07-21          11              0
# 516  train_Client_100074   2017-11-22          40              0
# 517  train_Client_100074   2017-11-22          11              0
# 518  train_Client_100074   2018-03-23          40              0
# 519  train_Client_100074   2018-03-23          11              0
# 520  train_Client_100074   2018-07-18          40              0
# 521  train_Client_100074   2018-07-18          11              0
# 522  train_Client_100074   2018-11-28          40              0
# 523  train_Client_100074   2018-11-28          11              0
# 524  train_Client_100074   2019-03-26          11              0
# 525  train_Client_100074   2019-03-26          40              0
# 526  train_Client_100074   2019-07-29          11              0
# 527  train_Client_100074   2019-07-29          40              0
#
#      counter_code  reading_remarque  counter_coefficient  \
# 496           207                 9                    1
# 497             5                 9                    1
# 498           207                 9                    1
# 499             5                 9                    1
# 500             5                 9                    1
# 501           207                 9                    1
# 502             5                 9                    1
# 503           207                 9                    1
# 504             5                 9                    1
# 505           207                 9                    1
# 506             5                 9                    1
# 507           207                 9                    1
# 508             5                 9                    1
# 509           207                 9                    1
# 510           207                 9                    1
# 511             5                 9                    1
# 512             5                 9                    1
# 513           207                 9                    1
# 514             5                 9                    1
# 515           207                 9                    1
# 516             5                 9                    1
# 517           207                 9                    1
# 518             5                 9                    1
# 519           207                 9                    1
# 520             5                 9                    1
# 521           207                 9                    1
# 522             5                 9                    1
# 523           207                 9                    1
# 524           207                 9                    1
# 525             5                 9                    1
# 526           207                 9                    1
# 527             5                 9                    1
#
#      consommation_level_1  consommation_level_2  consommation_level_3  \
# 496                    41                     0                     0
# 497                    60                     0                     0
# 498                    36                     0                     0
# 499                     8                     0                     0
# 500                   158                     0                     0
# 501                   800                   173                     0
# 502                    17                     0                     0
# 503                   168                     0                     0
# 504                    77                     0                     0
# 505                   350                     0                     0
# 506                    80                     0                     0
# 507                   229                     0                     0
# 508                    47                     0                     0
# 509                   303                     0                     0
# 510                   259                     0                     0
# 511                    40                     0                     0
# 512                   115                     0                     0
# 513                   309                     0                     0
# 514                    58                     0                     0
# 515                   333                     0                     0
# 516                    60                     0                     0
# 517                   376                     0                     0
# 518                   148                     0                     0
# 519                   350                     0                     0
# 520                    55                     0                     0
# 521                   363                     0                     0
# 522                    52                     0                     0
# 523                   458                     0                     0
# 524                   252                     0                     0
# 525                    93                     0                     0
# 526                   357                     0                     0
# 527                    56                     0                     0
#
#      consommation_level_4  old_index counter_type  disrict  client_catg  \
# 496                     0         36         ELEC       63           11
# 497                     0          8          GAZ       63           11
# 498                     0          0         ELEC       63           11
# 499                     0          0          GAZ       63           11
# 500                     0         68          GAZ       63           11
# 501                     0         77         ELEC       63           11
# 502                     0        226          GAZ       63           11
# 503                     0       1050         ELEC       63           11
# 504                     0        243          GAZ       63           11
# 505                     0       1218         ELEC       63           11
# 506                     0        320          GAZ       63           11
# 507                     0       1568         ELEC       63           11
# 508                     0        400          GAZ       63           11
# 509                     0       1797         ELEC       63           11
# 510                     0       2100         ELEC       63           11
# 511                     0        447          GAZ       63           11
# 512                     0        487          GAZ       63           11
# 513                     0       2359         ELEC       63           11
# 514                     0        602          GAZ       63           11
# 515                     0       2668         ELEC       63           11
# 516                     0        660          GAZ       63           11
# 517                     0       3001         ELEC       63           11
# 518                     0        720          GAZ       63           11
# 519                     0       3377         ELEC       63           11
# 520                     0        868          GAZ       63           11
# 521                     0       3727         ELEC       63           11
# 522                     0        923          GAZ       63           11
# 523                     0       4090         ELEC       63           11
# 524                     0       4548         ELEC       63           11
# 525                     0        975          GAZ       63           11
# 526                     0       4800         ELEC       63           11
# 527                     0       1068          GAZ       63           11
#
#      region creation_date  target  days_since_previous_invoice  \
# 496     312    2014-04-07     0.0                          NaN
# 497     312    2014-04-07     0.0                          0.0
# 498     312    2014-04-07     0.0                        193.0
# 499     312    2014-04-07     0.0                          0.0
# 500     312    2014-04-07     0.0                        249.0
# 501     312    2014-04-07     0.0                          0.0
# 502     312    2014-04-07     0.0                        115.0
# 503     312    2014-04-07     0.0                          0.0
# 504     312    2014-04-07     0.0                        125.0
# 505     312    2014-04-07     0.0                          0.0
# 506     312    2014-04-07     0.0                        120.0
# 507     312    2014-04-07     0.0                          0.0
# 508     312    2014-04-07     0.0                        124.0
# 509     312    2014-04-07     0.0                          0.0
# 510     312    2014-04-07     0.0                        120.0
# 511     312    2014-04-07     0.0                          0.0
# 512     312    2014-04-07     0.0                        120.0
# 513     312    2014-04-07     0.0                          0.0
# 514     312    2014-04-07     0.0                        120.0
# 515     312    2014-04-07     0.0                          0.0
# 516     312    2014-04-07     0.0                        124.0
# 517     312    2014-04-07     0.0                          0.0
# 518     312    2014-04-07     0.0                        121.0
# 519     312    2014-04-07     0.0                          0.0
# 520     312    2014-04-07     0.0                        117.0
# 521     312    2014-04-07     0.0                          0.0
# 522     312    2014-04-07     0.0                        133.0
# 523     312    2014-04-07     0.0                          0.0
# 524     312    2014-04-07     0.0                        118.0
# 525     312    2014-04-07     0.0                          0.0
# 526     312    2014-04-07     0.0                        125.0
# 527     312    2014-04-07     0.0                          0.0
#
#      months_since_acc_creation
# 496                         -3
# 497                         -3
# 498                          3
# 499                          3
# 500                         11
# 501                         11
# 502                         15
# 503                         15
# 504                         19
# 505                         19
# 506                         23
# 507                         23
# 508                         27
# 509                         27
# 510                         31
# 511                         31
# 512                         35
# 513                         35
# 514                         39
# 515                         39
# 516                         43
# 517                         43
# 518                         47
# 519                         47
# 520                         51
# 521                         51
# 522                         55
# 523                         55
# 524                         59
# 525                         59
# 526                         63
# 527                         63

# %%
data_df = data_df.drop(["invoice_date", "creation_date", "target"], axis = 1)

# %%
data_df.head()
# Out:
#          client_id invoice_date  tarif_type counter_statue  counter_code  \
# 0  train_Client_10   2005-11-10          11              0           203
# 1  train_Client_10   2006-06-19          11              0           203
# 2  train_Client_10   2007-06-18          11              0           203
# 3  train_Client_10   2007-10-16          11              0           203
# 4  train_Client_10   2008-02-15          11              0           203
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0                 6                    1                   459
# 1                 6                    1                   931
# 2                 6                    1                  1355
# 3                 6                    1                   476
# 4                 6                    1                   761
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index counter_type  disrict  client_catg  region creation_date  target  \
# 0      25515         ELEC       62           11     301    1986-03-13     0.0
# 1      25974         ELEC       62           11     301    1986-03-13     0.0
# 2      26905         ELEC       62           11     301    1986-03-13     0.0
# 3      28260         ELEC       62           11     301    1986-03-13     0.0
# 4      28736         ELEC       62           11     301    1986-03-13     0.0
#
#    days_since_previous_invoice  months_since_acc_creation
# 0                          NaN                        236
# 1                        221.0                        243
# 2                        364.0                        255
# 3                        120.0                        259
# 4                        122.0                        263

# %%
all_vcs = dict(data_df["client_id"].value_counts())

# %%
short_accs = {key: all_vcs[key] for key in all_vcs if all_vcs[key] <= 1}

# %%
len(short_accs)
# Out:
# 1012

# %%
short_accs_list = short_accs.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-7c1091b0814d> in <module>
# ----> 1 short_accs_list = short_accs.keys().tolist()
#
# AttributeError: 'dict_keys' object has no attribute 'tolist'

# %%
short_accs_list
# Out:
# dict_keys(['train_Client_72062', 'train_Client_83692', 'train_Client_42526', 'train_Client_38482', 'train_Client_35275', 'train_Client_98874', 'train_Client_66627', 'train_Client_92647', 'train_Client_63802', 'train_Client_48732', 'train_Client_2584', 'train_Client_130032', 'train_Client_110346', 'train_Client_103519', 'train_Client_51871', 'train_Client_70198', 'train_Client_82330', 'train_Client_19462', 'train_Client_114250', 'train_Client_15803', 'train_Client_97912', 'train_Client_40673', 'train_Client_95816', 'train_Client_83318', 'train_Client_13197', 'train_Client_96288', 'train_Client_105663', 'train_Client_38822', 'train_Client_95005', 'train_Client_29042', 'train_Client_78354', 'train_Client_67409', 'train_Client_64523', 'train_Client_134523', 'train_Client_87334', 'train_Client_18914', 'train_Client_50023', 'train_Client_55786', 'train_Client_90949', 'train_Client_29922', 'train_Client_126641', 'train_Client_6815', 'train_Client_110121', 'train_Client_80846', 'train_Client_8512', 'train_Client_50751', 'train_Client_26105', 'train_Client_113071', 'train_Client_12710', 'train_Client_117193', 'train_Client_130073', 'train_Client_80816', 'train_Client_43121', 'train_Client_59747', 'train_Client_53552', 'train_Client_57233', 'train_Client_21912', 'train_Client_110146', 'train_Client_128824', 'train_Client_65303', 'train_Client_112179', 'train_Client_30972', 'train_Client_6359', 'train_Client_97277', 'train_Client_63580', 'train_Client_31440', 'train_Client_44674', 'train_Client_131572', 'train_Client_78494', 'train_Client_61849', 'train_Client_67400', 'train_Client_14775', 'train_Client_49593', 'train_Client_57003', 'train_Client_79896', 'train_Client_79164', 'train_Client_69815', 'train_Client_122679', 'train_Client_1145', 'train_Client_13975', 'train_Client_34626', 'train_Client_24813', 'train_Client_24687', 'train_Client_123796', 'train_Client_41959', 'train_Client_66580', 'train_Client_115922', 'train_Client_107139', 'train_Client_69180', 'train_Client_66561', 'train_Client_29108', 'train_Client_24550', 'train_Client_123851', 'train_Client_67294', 'train_Client_116393', 'train_Client_27541', 'train_Client_75642', 'train_Client_42059', 'train_Client_57193', 'train_Client_60920', 'train_Client_8820', 'train_Client_50888', 'train_Client_82068', 'train_Client_75651', 'train_Client_2522', 'train_Client_116881', 'train_Client_69538', 'train_Client_56615', 'train_Client_118648', 'train_Client_13416', 'train_Client_43759', 'train_Client_11635', 'train_Client_17827', 'train_Client_16171', 'train_Client_104236', 'train_Client_124399', 'train_Client_43824', 'train_Client_132611', 'train_Client_17603', 'train_Client_3041', 'train_Client_103251', 'train_Client_98864', 'train_Client_46739', 'train_Client_102694', 'train_Client_99748', 'train_Client_18319', 'train_Client_126052', 'train_Client_88264', 'train_Client_25476', 'train_Client_124252', 'train_Client_103828', 'train_Client_23329', 'train_Client_30538', 'train_Client_85024', 'train_Client_104569', 'train_Client_128329', 'train_Client_123442', 'train_Client_129459', 'train_Client_6525', 'train_Client_47629', 'train_Client_66097', 'train_Client_70216', 'train_Client_80484', 'train_Client_52297', 'train_Client_32246', 'train_Client_90576', 'train_Client_17606', 'train_Client_126733', 'train_Client_88247', 'train_Client_110203', 'train_Client_94080', 'train_Client_53371', 'train_Client_79458', 'train_Client_75969', 'train_Client_133383', 'train_Client_62801', 'train_Client_99101', 'train_Client_72835', 'train_Client_74842', 'train_Client_106707', 'train_Client_17335', 'train_Client_106384', 'train_Client_63138', 'train_Client_113633', 'train_Client_89529', 'train_Client_76899', 'train_Client_49009', 'train_Client_48722', 'train_Client_65308', 'train_Client_5692', 'train_Client_1857', 'train_Client_14407', 'train_Client_106317', 'train_Client_126541', 'train_Client_98557', 'train_Client_60624', 'train_Client_105012', 'train_Client_30834', 'train_Client_13478', 'train_Client_2395 ...

# %%
data_df.to_csv("data.csv", index = False)
